# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
#your code here
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df = pd.read_csv("Cars.csv")

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code hpere
print(df.columns)
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df.set_index ("name")
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
# [398 rows x 8 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
print(df['mpg'].unique())
# Out:
# [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['hp_per_weight']=df['horsepower']/df['weight']
df.set_index('hp_per_weight')
# Out:
#                 mpg  cylinders  displacement  horsepower  weight  \
# hp_per_weight
# 0.037100       18.0          8         307.0       130.0    3504
# 0.044679       15.0          8         350.0       165.0    3693
# 0.043655       18.0          8         318.0       150.0    3436
# 0.043694       16.0          8         304.0       150.0    3433
# 0.040591       17.0          8         302.0       140.0    3449
# ...             ...        ...           ...         ...     ...
# 0.030824       27.0          4         140.0        86.0    2790
# 0.024413       44.0          4          97.0        52.0    2130
# 0.036601       32.0          4         135.0        84.0    2295
# 0.030095       28.0          4         120.0        79.0    2625
# 0.030147       31.0          4         119.0        82.0    2720
#
#                acceleration  model_year  origin                       name
# hp_per_weight
# 0.037100               12.0          70     usa  chevrolet chevelle malibu
# 0.044679               11.5          70     usa          buick skylark 320
# 0.043655               11.0          70     usa         plymouth satellite
# 0.043694               12.0          70     usa              amc rebel sst
# 0.040591               10.5          70     usa                ford torino
# ...                     ...         ...     ...                        ...
# 0.030824               15.6          82     usa            ford mustang gl
# 0.024413               24.6          82  europe                  vw pickup
# 0.036601               11.6          82     usa              dodge rampage
# 0.030095               18.6          82     usa                ford ranger
# 0.030147               19.4          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
max_hp = df['horsepower'].max()
car_name=df.loc[df['horsepower']==max_hp,'name'].values[0]
print("car with highest horsepower",car_name)
# Out:
# car with highest horsepower pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here
df.loc[df['mpg']>=35]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 54   35.0          4          72.0        69.0    1613          18.0
# 218  36.0          4          79.0        58.0    1825          18.6
# 244  43.1          4          90.0        48.0    1985          21.5
# 245  36.1          4          98.0        66.0    1800          14.4
# 247  39.4          4          85.0        70.0    2070          18.6
# 248  36.1          4          91.0        60.0    1800          16.4
# 295  35.7          4          98.0        80.0    1915          14.4
# 304  37.3          4          91.0        69.0    2130          14.7
# 309  41.5          4          98.0        76.0    2144          14.7
# 310  38.1          4          89.0        60.0    1968          18.8
# 312  37.2          4          86.0        65.0    2019          16.4
# 320  37.0          4         119.0        92.0    2434          15.0
# 322  46.6          4          86.0        65.0    2110          17.9
# 324  40.8          4          85.0        65.0    2110          19.2
# 325  44.3          4          90.0        48.0    2085          21.7
# 326  43.4          4          90.0        48.0    2335          23.7
# 327  36.4          5         121.0        67.0    2950          19.9
# 329  44.6          4          91.0        67.0    1850          13.8
# 330  40.9          4          85.0         NaN    1835          17.3
# 335  35.0          4         122.0        88.0    2500          15.1
# 343  39.1          4          79.0        58.0    1755          16.9
# 344  39.0          4          86.0        64.0    1875          16.4
# 345  35.1          4          81.0        60.0    1760          16.1
# 347  37.0          4          85.0        65.0    1975          19.4
# 348  37.7          4          89.0        62.0    2050          17.3
# 375  36.0          4         105.0        74.0    1980          15.3
# 376  37.0          4          91.0        68.0    2025          18.2
# 378  38.0          4         105.0        63.0    2125          14.7
# 379  36.0          4          98.0        70.0    2125          17.3
# 380  36.0          4         120.0        88.0    2160          14.5
# 381  36.0          4         107.0        75.0    2205          14.5
# 383  38.0          4          91.0        67.0    1965          15.0
# 385  38.0          4          91.0        67.0    1995          16.2
# 387  38.0          6         262.0        85.0    3015          17.0
# 391  36.0          4         135.0        84.0    2370          13.0
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                               name  hp_per_weight
# 54           71   japan                        datsun 1200       0.042777
# 218          77  europe                      renault 5 gtl       0.031781
# 244          78  europe    volkswagen rabbit custom diesel       0.024181
# 245          78     usa                        ford fiesta       0.036667
# 247          78   japan                     datsun b210 gx       0.033816
# 248          78   japan                   honda civic cvcc       0.033333
# 295          79     usa        dodge colt hatchback custom       0.041775
# 304          79  europe                 fiat strada custom       0.032394
# 309          80  europe                          vw rabbit       0.035448
# 310          80   japan              toyota corolla tercel       0.030488
# 312          80   japan                         datsun 310       0.032194
# 320          80   japan               datsun 510 hatchback       0.037798
# 322          80   japan                          mazda glc       0.030806
# 324          80   japan                         datsun 210       0.030806
# 325          80  europe               vw rabbit c (diesel)       0.023022
# 326          80  europe                 vw dasher (diesel)       0.020557
# 327          80  europe                audi 5000s (diesel)       0.022712
# 329          80   japan                honda civic 1500 gl       0.036216
# 330          80  europe               renault lecar deluxe            NaN
# 335          80  europe                  triumph tr7 coupe       0.035200
# 343          81   japan                     toyota starlet       0.033048
# 344          81     usa                     plymouth champ       0.034133
# 345          81   japan                   honda civic 1300       0.034091
# 347          81   japan                     datsun 210 mpg       0.032911
# 348          81   japan                      toyota tercel       0.030244
# 375          82  europe                volkswagen rabbit l       0.037374
# 376          82   japan                 mazda glc custom l       0.033580
# 378          82     usa             plymouth horizon miser       0.029647
# 379          82     usa                     mercury lynx l       0.032941
# 380          82   japan                   nissan stanza xe       0.040741
# 381          82   japan                       honda accord       0.034014
# 383          82   japan                        honda civic       0.034097
# 385          82   japan                      datsun 310 gx       0.033584
# 387          82     usa  oldsmobile cutlass ciera (diesel)       0.028192
# 391          82     usa                  dodge charger 2.2       0.035443
# 394          82  europe                          vw pickup       0.024413

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
newdf=df[(df['horsepower']>100)&(df['weight']<3000)]
common_origin = newdf['origin'].mode()[0]
print(common_origin)
# Out:
# usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
mean=df[df['origin']=='japan']['acceleration'].mean()
new_rounded = round(mean,2)
print(new_rounded)
# Out:
# 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
avg_mpg_by_year = df.groupby('model_year')['mpg'].mean()
best_year = avg_mpg_by_year.idxmax()
highest_avg_mpg=avg_mpg_by_year.max()
print(highest_avg_mpg)
# Out:
# 33.69655172413793

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
median_mpg = df['mpg'].median()
filtered_df = df[df['mpg'] > median_mpg]
filtered_df['hp_per_weight'] = filtered_df['horsepower'] / filtered_df['weight']
max_ratio = filtered_df['hp_per_weight'].max()
best_cars = filtered_df[filtered_df['hp_per_weight'] == max_ratio]

print("Car(s) with the best horsepower-to-weight ratio and above-median mpg:")
print(best_cars)
# Out:
# Car(s) with the best horsepower-to-weight ratio and above-median mpg:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 23  26.0          4         121.0       113.0    2234          12.5
#
#     model_year  origin      name  hp_per_weight
# 23          70  europe  bmw 2002       0.050582
# C:\Users\AYUSH AGARWAL\AppData\Local\Temp\ipykernel_13840\1761449437.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['hp_per_weight'] = filtered_df['horsepower'] / filtered_df['weight']

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
#your code here
import seaborn as sns
import matplotlib.pyplot as plt
avg_mpg = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(10, 6))
sns.lineplot(data=avg_mpg, x='model_year', y='mpg', hue='origin', marker='o')

plt.title('Evolution of Average MPG Over Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
import seaborn as sns
import matplotlib.pyplot as plt

# Set the hue order
hue_order = ['japan', 'europe', 'usa']

# Create the scatterplot
plt.figure(figsize=(10, 6))
scatter = sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=hue_order,
    sizes=(20, 200),  # scale the dot sizes
    alpha=0.7,
    palette='Set1'
)

# Titles and labels
plt.title('Horsepower vs Weight (Colored by Origin, Sized by MPG)', fontsize=14)
plt.xlabel('Horsepower')
plt.ylabel('Weight')
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()

plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
#your code here
# Step 1: Group by car name and count appearances
name_year_counts = df.groupby('name')['model_year'].nunique()

# Step 2: Filter car names that appeared in more than one year
multi_year_cars = name_year_counts[name_year_counts > 1].index

# Step 3: Filter dataset to those cars only
filtered_df = df[df['name'].isin(multi_year_cars)]

# Step 4: Group by name and calculate std and mean of mpg
grouped = filtered_df.groupby('name')['mpg'].agg(['std', 'mean', 'count']).reset_index()

# Step 5: Filter for std < 1.0
consistent_cars = grouped[grouped['std'] < 1.0]

# Step 6: Rename and format columns for clarity
consistent_cars = consistent_cars.rename(columns={
    'name': 'Model Name',
    'std': 'MPG Std Dev',
    'mean': 'Average MPG',
    'count': 'Appearances'
})

# Step 7: Sort by appearances descending, then avg mpg descending
consistent_cars_sorted = consistent_cars.sort_values(
    by=['Appearances', 'Average MPG'],
    ascending=[False, False]
)

# Display the result
print(consistent_cars_sorted)
# Out:
#                    Model Name  MPG Std Dev  Average MPG  Appearances
# 26           ford galaxie 500     0.577350    14.333333            3
# 41          plymouth fury iii     0.577350    14.333333            3
# 49        toyota corolla 1200     0.707107    31.500000            2
# 35                  mazda 626     0.212132    31.450000            2
# 53          volkswagen rabbit     0.353553    29.250000            2
# 21               datsun pl510     0.000000    27.000000            2
# 45                  saab 99le     0.707107    24.500000            2
# 51             toyota mark ii     0.707107    19.500000            2
# 22                dodge aspen     0.353553    18.850000            2
# 10  chevrolet chevelle malibu     0.707107    17.500000            2
# 4            amc matador (sw)     0.707107    14.500000            2
# 28      ford gran torino (sw)     0.707107    13.500000            2
# 29                   ford ltd     0.707107    13.500000            2

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
